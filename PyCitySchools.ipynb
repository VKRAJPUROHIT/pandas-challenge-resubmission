# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# Files to Load 
school_data_to_load = "../Resources/schools_complete.csv"
student_data_to_load = "../Resources/students_complete.csv"

# %%
# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load,index_col="school_name")
student_data = pd.read_csv(student_data_to_load)

# %%
# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
#sort values alphabetically
school_data_complete=school_data_complete.sort_values(by="school_name")

# %%
#Get all school names 
school_names=school_data_complete["school_name"].unique()

# %%
#Calculate the number of schools   
total_number_of_schools=len(school_names)
print(total_number_of_schools)
# Out:
# 15

# %%
#Calculate the number of students 
total_number_of_students=school_data_complete["student_name"].count()
print(total_number_of_students)
# Out:
# 39170

# %%
#Calculate total budget
filter_school_df=school_data_complete.drop_duplicates(subset='school_name')
total_budget=filter_school_df["budget"].sum()
print(total_budget)
# Out:
# 24649428

# %%
#Calculate average math score 
average_math_score=school_data_complete["math_score"].mean()
print(average_math_score)
# Out:
# 78.98537145774827

# %%
#Calculate average reading score 
average_reading_score=school_data_complete["reading_score"].mean() 
print(average_reading_score)
# Out:
# 81.87784018381414

# %%
#Calculate number of students with passing math score 
names_math=school_data_complete[(school_data_complete['math_score']>=70)]
number_of_students_with_passing_math_score=len(names_math)
print(number_of_students_with_passing_math_score)
# Out:
# 29370

# %%
#Calculate percentage of students with passing math score
percent_math_70_or_greater=number_of_students_with_passing_math_score/total_number_of_students*100
print(percent_math_70_or_greater)
# Out:
# 74.9808526933878

# %%
#Calculate number of students with passing reading score 
names_reading=school_data_complete[(school_data_complete['reading_score']>=70)]
number_of_students_with_passing_reading_score=len(names_reading) 
print(number_of_students_with_passing_reading_score)
# Out:
# 33610

# %%
#Calculate percentage of students with passing reading score
percent_reading_70_or_greater=number_of_students_with_passing_reading_score/total_number_of_students*100 
print(percent_reading_70_or_greater)
# Out:
# 85.80546336482001

# %%
#Get the names of students with passing math AND reading
names_math_and_reading=school_data_complete[(school_data_complete['math_score']>=70) & (school_data_complete['reading_score']>=70)]

# %%
#Calculate the number of students with passing math AND reading
number_math_and_reading=len(names_math_and_reading)
print(number_math_and_reading)
# Out:
# 25528

# %%
#Calculate the percentage of students passing math AND reading  
percent_math_and_reading=number_math_and_reading/total_number_of_students*100
print(percent_math_and_reading)
# Out:
# 65.17232575950983

# %%
#Create a data frame to hold districy summary details
district_summary_df=pd.DataFrame({"Total Schools":total_number_of_schools,                                 
                                  "Total Students":total_number_of_students,
                                  "Total Budget": total_budget,
                                  "Average Math Score": average_math_score,
                                  "Average Reading Score": average_reading_score,
                                  "% Passing Math": percent_math_70_or_greater,
                                  "% Passing Reading": percent_reading_70_or_greater,
                                  "% Overall Passing": percent_math_and_reading},index=[0])    
district_summary_df['Total Budget'] = (district_summary_df['Total Budget']).apply(lambda x: '${:,.2f}'.format(x))
district_summary_df['Total Students'] = (district_summary_df['Total Students']).apply(lambda x: '{:,}'.format(x))
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
#group by school type
school_type=school_data_complete.groupby(by=["school_name"])["type"].max()

# %%
#Calculate average math score for each school
average_school_math=school_data_complete.groupby(by=["school_name"])["math_score"].mean()

# %%
#Calculate average reading score for each school
average_school_reading=school_data_complete.groupby(by=["school_name"])["reading_score"].mean()

# %%
#calculate number of students passing math
math_score_school_wise_70_above=school_data_complete[(school_data_complete['math_score']>=70) & ((school_data_complete['school_name']=='Bailey High School')|(school_data_complete['school_name']=='Cabrera High School')|(school_data_complete['school_name']=='Figueroa High School')|(school_data_complete['school_name']=='Ford High School')|(school_data_complete['school_name']=='Griffin High School')|(school_data_complete['school_name']=='Hernandez High School')|(school_data_complete['school_name']=='Holden High School')|(school_data_complete['school_name']=='Huang High School')|(school_data_complete['school_name']=='Johnson High School')|(school_data_complete['school_name']=='Pena High School')|(school_data_complete['school_name']=='Rodriguez High School')|(school_data_complete['school_name']=='Shelton High School')|(school_data_complete['school_name']=='Thomas High School')|(school_data_complete['school_name']=='Wilson High School')|(school_data_complete['school_name']=='Wright High School'))]                            
                         
math_passing_students = math_score_school_wise_70_above.groupby(by=["school_name"]).count()
math_passing_students1=math_passing_students[['math_score']]

# %%
#calculate number of students passing reading
reading_score_school_wise_70_above=school_data_complete[(school_data_complete['reading_score']>=70) & ((school_data_complete['school_name']=='Bailey High School')|(school_data_complete['school_name']=='Cabrera High School')|(school_data_complete['school_name']=='Figueroa High School')|(school_data_complete['school_name']=='Ford High School')|(school_data_complete['school_name']=='Griffin High School')|(school_data_complete['school_name']=='Hernandez High School')|(school_data_complete['school_name']=='Holden High School')|(school_data_complete['school_name']=='Huang High School')|(school_data_complete['school_name']=='Johnson High School')|(school_data_complete['school_name']=='Pena High School')|(school_data_complete['school_name']=='Rodriguez High School')|(school_data_complete['school_name']=='Shelton High School')|(school_data_complete['school_name']=='Thomas High School')|(school_data_complete['school_name']=='Wilson High School')|(school_data_complete['school_name']=='Wright High School'))]
reading_passing_students = reading_score_school_wise_70_above.groupby(by=["school_name"]).count()
reading_passing_students1=reading_passing_students[['reading_score']]

# %%
#calculate number of students passing both math and reading
math_and_reading_pass_students=names_math_and_reading['school_name'].value_counts()

# %%
#calculate school size
school_capacity=school_data_complete.groupby(by=["school_name"])["size"].max()

# %%
#groupby school budget 
total_school_budget=school_data_complete.groupby(by=['school_name'])['budget'].max()

# %%
#calculate per student budget
per_student_budget=total_school_budget/school_capacity

# %%
#build a data frame for school summary
school_summary_df=pd.DataFrame({"School Type": school_type,
                                "Total Students": school_capacity,
                                "Total School Budget": total_school_budget,
                                "Per Student Budget":per_student_budget,
                                "Average Math Score": average_school_math, 
                                "Average Reading Score":average_school_reading,},
                               index=['Bailey High School','Cabrera High School','Figueroa High School','Ford High School','Griffin High School','Hernandez High School','Holden High School','Huang High School','Johnson High School','Pena High School','Rodriguez High School','Shelton High School','Thomas High School','Wilson High School','Wright High School'])  
school_summary_df['math pass']=math_passing_students1
school_summary_df['reading pass']=reading_passing_students1
percent_math_pass=school_summary_df['math pass']/school_summary_df['Total Students']*100
school_summary_df['% Passing Math']=percent_math_pass
percent_reading_pass=school_summary_df['reading pass']/school_summary_df['Total Students']*100
school_summary_df['% Passing Reading']=percent_reading_pass

# %%
#calculate number of overall passing students
school_summary_df["overall passing"]=math_and_reading_pass_students

# %%
#calculate percent overall passing
percent_overall=school_summary_df["overall passing"]/school_summary_df['Total Students']*100

# %%
#add %overall passing column and format the currency columns
school_summary_df['% Overall Passing']=percent_overall
school_summary_df['Total School Budget'] = (school_summary_df['Total School Budget']).apply(lambda x: '${:,.2f}'.format(x))
school_summary_df['Per Student Budget'] = (school_summary_df['Per Student Budget']).apply(lambda x: '${:,.2f}'.format(x))

# %%
#drop unwanted columns
school_summary_df.drop(columns=['math pass','reading pass','overall passing' ])
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
#get initial data frame for top performing schools 
top_performing_schools=school_summary_df.sort_values(by=['% Overall Passing'], ascending=False).head(5)

# %%
#drop unwanted columns
top_performing_schools.drop(columns=['math pass','reading pass','overall passing' ])
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
#get initial data frame for bottom performing schools
bottom_performing_schools=school_summary_df.sort_values(by=['% Overall Passing'], ascending=True).head(5)

# %%
#drop unwanted columns
bottom_performing_schools.drop(columns=['math pass','reading pass','overall passing' ])
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %%
#calculate average math scores for grades 9th,10th,11th,12th
s_9_df=school_data_complete[school_data_complete['grade'].isin(['9th'])]
s_9_grouped_df=s_9_df.groupby(by=['school_name'])['math_score'].mean()
s_10_df=school_data_complete[school_data_complete['grade'].isin(['10th'])]
s_10_grouped_df=s_10_df.groupby(by=['school_name'])['math_score'].mean()
s_11_df=school_data_complete[school_data_complete['grade'].isin(['11th'])]
s_11_grouped_df=s_11_df.groupby(by=['school_name'])['math_score'].mean()
s_12_df=school_data_complete[school_data_complete['grade'].isin(['12th'])]
s_12_grouped_df=s_12_df.groupby(by=['school_name'])['math_score'].mean()

# %%
#Final data frame of math scores by grade
math_scores_by_grade_df=pd.DataFrame({"9th": s_9_grouped_df,
                                      "10th":s_10_grouped_df,
                                      "11th":s_11_grouped_df,
                                      "12th":s_12_grouped_df,},                                
                                      index=['Bailey High School','Cabrera High School','Figueroa High School','Ford High School','Griffin High School','Hernandez High School','Holden High School','Huang High School','Johnson High School','Pena High School','Rodriguez High School','Shelton High School','Thomas High School','Wilson High School','Wright High School'])  
math_scores_by_grade_df
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
#calculate average reading scores for grades 9th,10th,11th,12th
s_9_df=school_data_complete[school_data_complete['grade'].isin(['9th'])]
s_9_grouped_rd_df=s_9_df.groupby(by=['school_name'])['reading_score'].mean()
s_10_df=school_data_complete[school_data_complete['grade'].isin(['10th'])]
s_10_grouped_rd_df=s_10_df.groupby(by=['school_name'])['reading_score'].mean()
s_11_df=school_data_complete[school_data_complete['grade'].isin(['11th'])]
s_11_grouped_rd_df=s_11_df.groupby(by=['school_name'])['reading_score'].mean()
s_12_df=school_data_complete[school_data_complete['grade'].isin(['12th'])]
s_12_grouped_rd_df=s_12_df.groupby(by=['school_name'])['reading_score'].mean()

# %%
#Final data frame of reading scores by grade
reading_scores_by_grade_df=pd.DataFrame({"9th": s_9_grouped_rd_df,
                                      "10th":s_10_grouped_rd_df,
                                      "11th":s_11_grouped_rd_df,
                                      "12th":s_12_grouped_rd_df,},                                
                                      index=['Bailey High School','Cabrera High School','Figueroa High School','Ford High School','Griffin High School','Hernandez High School','Holden High School','Huang High School','Johnson High School','Pena High School','Rodriguez High School','Shelton High School','Thomas High School','Wilson High School','Wright High School']) 
reading_scores_by_grade_df
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
#calculate per student costing and make a new column
school_data_complete['Per Student Costing']=school_data_complete['budget']/school_data_complete['size']

# %%
#group data frame by per student costing
grouped_school_data_complete_by_per_student_cost=school_data_complete.groupby(by='Per Student Costing')

# %%
#calculate average math score by per student cost
average_math_score_by_per_student_cost=grouped_school_data_complete_by_per_student_cost['math_score'].mean()

# %%
#calculate average reading score by per student cost
average_reading_score_by_per_student_cost=grouped_school_data_complete_by_per_student_cost['reading_score'].mean()

# %%
#calculate % math pass by per student cost
name_of_students_passing_math1=school_data_complete[school_data_complete['math_score']>=70]
number_of_students_passing_math_by_per_student_cost=name_of_students_passing_math1.groupby(by=['Per Student Costing']).count()
total_number_of_students_by_per_student_cost=grouped_school_data_complete_by_per_student_cost['Per Student Costing'].count()
percent_pass_math_by_per_student_cost=number_of_students_passing_math_by_per_student_cost['math_score']/total_number_of_students_by_per_student_cost*100

# %%
#calculate % reading pass by per student cost
name_of_students_passing_reading1=school_data_complete[school_data_complete['reading_score']>=70]
number_of_students_passing_reading_by_per_student_cost=name_of_students_passing_reading1.groupby(by=['Per Student Costing']).count()
total_number_of_students_by_per_student_cost=grouped_school_data_complete_by_per_student_cost['Per Student Costing'].count()
percent_pass_reading_by_per_student_cost=number_of_students_passing_reading_by_per_student_cost['reading_score']/total_number_of_students_by_per_student_cost*100

# %%
#calculate % overall pass by per student cost
name_of_students_passing_math_and_reading1=school_data_complete[(school_data_complete['reading_score']>=70)&(school_data_complete['math_score']>=70)]
number_of_students_passing_math_and_reading_by_per_student_cost=name_of_students_passing_math_and_reading1.groupby(by=['Per Student Costing']).count()
total_number_of_students_by_per_student_cost=grouped_school_data_complete_by_per_student_cost['Per Student Costing'].count()
percent_pass_math_and_reading_by_per_student_cost=number_of_students_passing_math_and_reading_by_per_student_cost['reading_score']/total_number_of_students_by_per_student_cost*100

# %%
#initial construction of data frame for scores by school spending 
scores_by_school_spending_df=pd.DataFrame({"Average Math Score":average_math_score_by_per_student_cost,
                                           "Average Reading Score":average_reading_score_by_per_student_cost,
                                           "% Passing Math ":percent_pass_math_by_per_student_cost,
                                           "% Passing Reading":percent_pass_reading_by_per_student_cost,
                                           "% Overall Passing":percent_pass_math_and_reading_by_per_student_cost,}) 
scores_by_school_spending_df.reset_index()
# Out:
#     Per Student Costing  Average Math Score  Average Reading Score  \
# 0                 578.0           83.274201              83.989488
# 1                 581.0           83.803279              83.814988
# 2                 582.0           83.061895              83.975780
# 3                 583.0           83.682222              83.955000
# 4                 600.0           83.359455              83.725724
# 5                 609.0           83.839917              84.044699
# 6                 625.0           83.351499              83.816757
# 7                 628.0           77.048432              81.033963
# 8                 637.0           76.842711              80.744686
# 9                 638.0           83.418349              83.848930
# 10                639.0           76.711767              81.158020
# 11                644.0           77.102592              80.746258
# 12                650.0           77.072464              80.966394
# ...

# %%
# Create the bins in which Data will be held
# Bins are 0, 584, 629, 644, 675. 
x=np.array([578.0,581.0,582.0,583.0,600.0,609.0,625.0,628.0,637.0,638.0,639.0,644.0,650.0,652.0,655.0])
bins = [0.0, 584.0, 629.0, 644.0, 675.0]

# Create the names for the five bins
group_names = ["<$584", "585-629", "630-644", "645-675"]

# %%
##Bin values into discrete school spending intervals
scores_by_school_spending_df['Spending Ranges(Per Student)']=pd.cut(x,bins,labels=group_names,include_lowest=True)

# %%
#Final data frame for scores by school spending
scores_by_school_spending_df=scores_by_school_spending_df.groupby("Spending Ranges(Per Student)") 
scores_by_school_spending_df.mean()
# Out:
#                               Average Math Score  Average Reading Score  \
# Spending Ranges(Per Student)
# <$584                                  83.455399              83.933814
# 585-629                                81.899826              83.155286
# 630-644                                78.518855              81.624473
# 645-675                                76.997210              81.027843
#
#                               % Passing Math   % Passing Reading  \
# Spending Ranges(Per Student)
# <$584                               93.460096          96.610877
# 585-629                             87.133538          92.718205
# 630-644                             73.484209          84.391793
# 645-675                             66.164813          81.133951
#
#                               % Overall Passing
# Spending Ranges(Per Student)
# <$584                                 90.369459
# 585-629                               81.418596
# ...

# %%
#group the data frame by school size
grouped_school_data_complete_by_school_size=school_data_complete.groupby(by='size')

# %%
#calculate average math score by school size
average_math_score_by_school_size=grouped_school_data_complete_by_school_size['math_score'].mean()

# %%
#calculate average reading score by school size
average_reading_score_by_school_size=grouped_school_data_complete_by_school_size['reading_score'].mean()

# %%
#calculate % math pass by school size  
name_of_students_passing_math2=school_data_complete[school_data_complete['math_score']>=70]
number_of_students_passing_math_by_school_size=name_of_students_passing_math2.groupby(by=['size']).count()
total_number_of_students_by_school_size=grouped_school_data_complete_by_school_size['size'].count()
percent_pass_math_by_school_size=number_of_students_passing_math_by_school_size['math_score']/total_number_of_students_by_school_size*100

# %%
#calculate % reading pass by school size 
name_of_students_passing_reading2=school_data_complete[school_data_complete['reading_score']>=70]
number_of_students_passing_reading_by_school_size=name_of_students_passing_reading2.groupby(by=['size']).count()
total_number_of_students_by_school_size=grouped_school_data_complete_by_school_size['size'].count()
percent_pass_reading_by_school_size=number_of_students_passing_reading_by_school_size['reading_score']/total_number_of_students_by_school_size*100

# %%
#Calculate % overall passing by school size
name_of_students_passing_math_and_reading2=school_data_complete[(school_data_complete['reading_score']>=70)&(school_data_complete['math_score']>=70)]
number_of_students_passing_math_and_reading_by_school_size=name_of_students_passing_math_and_reading2.groupby(by=['size']).count()
total_number_of_students_by_school_size=grouped_school_data_complete_by_school_size['size'].count()
percent_pass_math_and_reading_by_school_size=number_of_students_passing_math_and_reading_by_school_size['reading_score']/total_number_of_students_by_school_size*100

# %%
# initial construction of data frame for Scores by School Size
scores_by_school_size_df=pd.DataFrame({"Average Math Score":average_math_score_by_school_size,
                                       "Average Reading Score":average_reading_score_by_school_size,
                                       "% Passing Math ":percent_pass_math_by_school_size,
                                       "% Passing Reading":percent_pass_reading_by_school_size,
                                       "% Overall Passing":percent_pass_math_and_reading_by_school_size})            
                                          
scores_by_school_size_df.reset_index()
# Out:
#     size  Average Math Score  Average Reading Score  % Passing Math   \
# 0    427           83.803279              83.814988        92.505855
# 1    962           83.839917              84.044699        94.594595
# 2   1468           83.351499              83.816757        93.392371
# 3   1635           83.418349              83.848930        93.272171
# 4   1761           83.359455              83.725724        93.867121
# 5   1800           83.682222              83.955000        93.333333
# 6   1858           83.061895              83.975780        94.133477
# 7   2283           83.274201              83.989488        93.867718
# 8   2739           77.102592              80.746258        68.309602
# 9   2917           76.629414              81.182722        65.683922
# 10  2949           76.711767              81.158020        65.988471
# 11  3999           76.842711              80.744686        66.366592
# 12  4635           77.289752              80.934412        66.752967
# ...

# %%
# Create the bins in which Data will be held
# Bins are 0, 584, 629, 644, 675.   
bins = [0, 1000, 2000, 5000]

x1=np.array([427,962,1468,1635,1761,1800,1858,2283,2739,2917,2949,3999,4635,4761,4976])

# Create the names for the three bins
group_names1 = ["Small(<1000)","Medium(1000-2000)","Large(2000-5000)"]

# %%
#Bin values into discrete school size intervals
scores_by_school_size_df['School Size']=pd.cut(x1,bins,labels=group_names1,include_lowest=True)

# %%
#Final data frame for Scores by School Size
scores_by_school_size_df=scores_by_school_size_df.groupby(by=["School Size"]).mean() 
scores_by_school_size_df
# Out:
#                    Average Math Score  Average Reading Score  % Passing Math   \
# School Size
# Small(<1000)                83.821598              83.929843        93.550225
# Medium(1000-2000)           83.374684              83.864438        93.599695
# Large(2000-5000)            77.746417              81.344493        69.963361
#
#                    % Passing Reading  % Overall Passing
# School Size
# Small(<1000)               96.099437          89.883853
# Medium(1000-2000)          96.790680          90.621535
# Large(2000-5000)           82.766634          58.286003

# %%
#Let us group the data frame by type
grouped_school_data_complete_by_type=school_data_complete.groupby(by='type')

# %%
#Calculate average math score by type
average_math_score_by_type=grouped_school_data_complete_by_type['math_score'].mean()

# %%
#Calculate average reading score by type
average_reading_score_by_type=grouped_school_data_complete_by_type['reading_score'].mean()

# %%
#Calculate % math pass by type
name_of_students_passing_math3=school_data_complete[school_data_complete['math_score']>=70]
number_of_students_passing_math_by_type=name_of_students_passing_math3.groupby(by=['type']).count()
total_number_of_students_by_type=grouped_school_data_complete_by_type['type'].count()
percent_pass_math_by_type=number_of_students_passing_math_by_type['math_score']/total_number_of_students_by_type*100

# %%
#Calculate % reading pass by type
name_of_students_passing_reading3=school_data_complete[school_data_complete['reading_score']>=70]
number_of_students_passing_reading_by_type=name_of_students_passing_reading3.groupby(by=['type']).count()
total_number_of_students_by_type=grouped_school_data_complete_by_type['type'].count()
percent_pass_reading_by_type=number_of_students_passing_reading_by_type['reading_score']/total_number_of_students_by_type*100

# %%
#Calculate % overall passing by type 
name_of_students_passing_math_and_reading3=school_data_complete[(school_data_complete['reading_score']>=70)&(school_data_complete['math_score']>=70)]
number_of_students_passing_math_and_reading_by_type=name_of_students_passing_math_and_reading3.groupby(by=['type']).count()
total_number_of_students_by_type=grouped_school_data_complete_by_type['type'].count()
percent_pass_math_and_reading_by_type=number_of_students_passing_math_and_reading_by_type['reading_score']/total_number_of_students_by_type*100

# %%
#Final data frame by school type
scores_by_school_type_df=pd.DataFrame({"Average Math Score":average_math_score_by_type ,
                                       "Average Reading Score":average_reading_score_by_type,
                                       "% Passing Math ":percent_pass_math_by_type,
                                       "% Passing Reading":percent_pass_reading_by_type,
                                       "% Overall Passing":percent_pass_math_and_reading_by_type},
                                       index=['Charter','District'])
scores_by_school_type_df.index.name='School Type'                                          
scores_by_school_type_df
# Out:
#              Average Math Score  Average Reading Score  % Passing Math   \
# School Type
# Charter               83.406183              83.902821        93.701821
# District              76.987026              80.962485        66.518387
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.645891          90.560932
# District             80.905249          53.695878

# %%
#Observable trends
#1.Scores by School Spending: The academic performance of students in Math and Reading has actually deteriorated as the spending
# by schools on each student increased.This may suggest the students are spending more time on other activities like music.drama
# sports and are not focused on the academics 
#2.Scores by School Size: The academic performance of students in Math and Reading has deteriorated as the school size increased
# The difference is especially substantial from small/medium to large.This may suggest the students are not getting enough
# personal attention becuase of the high student-teacher ratio in the large schools
